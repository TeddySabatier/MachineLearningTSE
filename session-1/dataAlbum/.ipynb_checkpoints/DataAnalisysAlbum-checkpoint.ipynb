# %%
import pandas as pd
import matplotlib.pyplot as plt

dfAll = pd.read_csv(r'./albums.csv')
dfAll = dfAll.filter(regex='^(?!.*(Unnamed))', axis=1)

dfAlbum =dfAll[dfAll["project_type"].str.contains("album")]
dfEp =dfAll[dfAll["project_type"].str.contains("ep")]
dfMixtape=dfAll[dfAll["project_type"].str.contains("mixtape")]
dfTrack=dfAll[dfAll["project_type"].str.contains("track")]
dfRedux=dfAll[dfAll["project_type"].str.contains("redux")]
# Out:
#                spotify_id   youtube_id                       project_name  \
# 0  1B5Lwt0D1ZetRreaCBYobP  GMKfsj1fg5g                            all day
# 1  20r762YmB5HeofjMCiPMLv  Jo4S2qlQGs0  my beautiful dark twisted fantasy
# 4  5zi7WsKlIiUXv09tbGLKsE  _2RPGAA6p4E                            bastard
# 5  1JvYBgt86ujXdSWnuw5lhX  EZOQBqCPQHc                     777 volume one
# 7  53mU2L8Ngi8zFAD9JoXNqx  LwDNWYvFpYs         sex dreams and denim jeans
#
#                artist project_type  tracks  \
# 0           girl talk        album    14.0
# 1          kanye west        album    13.0
# 4  tyler, the creator        album    12.0
# 5             tonetta        album     1.0
# 7               uffie        album    16.0
#
#                                          project_art    year  rating
# 0  https://i.scdn.co/image/ab67616d000048510192ca...  2008.0     8.0
# 1  https://i.scdn.co/image/ab67616d00004851d9194a...  2010.0     6.0
# ...

# %%
dfAll.plot(y="year",kind='hist')
dfAll.plot(y="rating",kind='hist')
plt.show()
